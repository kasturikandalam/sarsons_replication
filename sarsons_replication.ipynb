# %%
"""
Replication of Figure 2: Relationship between Paper Composition and Tenure
From: Sarsons et al. (2021) - Gender Differences in Recognition for Group Work
"""

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import linregress
from sklearn.linear_model import LinearRegression
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')
